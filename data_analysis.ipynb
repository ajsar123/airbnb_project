# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
df=pd.read_csv('datasets.csv')

df.head(5)
# Out:
#              id                                               name    host_id  \
# 0  1.312228e+06         Rental unit in Brooklyn · ★5.0 · 1 bedroom    7130382
# 1  4.527754e+07  Rental unit in New York · ★4.67 · 2 bedrooms ·...   51501835
# 2  9.710000e+17  Rental unit in New York · ★4.17 · 1 bedroom · ...  528871354
# 3  3.857863e+06  Rental unit in New York · ★4.64 · 1 bedroom · ...   19902271
# 4  4.089661e+07  Condo in New York · ★4.91 · Studio · 1 bed · 1...   61391963
#
#             host_name neighbourhood_group       neighbourhood   latitude  \
# 0              Walter            Brooklyn        Clinton Hill  40.683710
# 1            Jeniffer           Manhattan      Hell's Kitchen  40.766610
# 2              Joshua           Manhattan             Chelsea  40.750764
# 3  John And Catherine           Manhattan  Washington Heights  40.835600
# 4      Stay With Vibe           Manhattan         Murray Hill  40.751120
#
# ...

# %%
df.shape
# Out:
# (20770, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20770 entries, 0 to 20769
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20770 non-null  float64
#  1   name                            20770 non-null  object
#  2   host_id                         20770 non-null  int64
#  3   host_name                       20770 non-null  object
#  4   neighbourhood_group             20770 non-null  object
#  5   neighbourhood                   20763 non-null  object
#  6   latitude                        20763 non-null  float64
#  7   longitude                       20763 non-null  float64
#  8   room_type                       20763 non-null  object
#  9   price                           20736 non-null  float64
#  10  minimum_nights                  20763 non-null  float64
#  11  number_of_reviews               20763 non-null  float64
# ...

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude          price  \
# count  2.077000e+04  2.077000e+04  20763.000000  20763.000000   20736.000000
# mean   3.033858e+17  1.749049e+08     40.726821    -73.939179     187.714940
# std    3.901221e+17  1.725657e+08      0.060293      0.061403    1023.245124
# min    2.595000e+03  1.678000e+03     40.500314    -74.249840      10.000000
# 25%    2.707260e+07  2.041184e+07     40.684159    -73.980755      80.000000
# 50%    4.992852e+07  1.086990e+08     40.722890    -73.949597     125.000000
# 75%    7.220000e+17  3.143997e+08     40.763106    -73.917475     199.000000
# max    1.050000e+18  5.504035e+08     40.911147    -73.713650  100000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    20763.000000       20763.000000       20763.000000
# mean        28.558493          42.610605           1.257589
# std         33.532697          73.523401           1.904472
# ...

# %% [markdown]
# #  Further data analysis and modeling code would go here

# %%
df.isnull().sum()
# Out:
# id                                 0
# name                               0
# host_id                            0
# host_name                          0
# neighbourhood_group                0
# neighbourhood                      7
# latitude                           7
# longitude                          7
# room_type                          7
# price                             34
# minimum_nights                     7
# number_of_reviews                  7
# last_review                        7
# reviews_per_month                  7
# calculated_host_listings_count     7
# availability_365                   7
# number_of_reviews_ltm              7
# license                            0
# rating                             0
# bedrooms                           0
# beds                               0
# baths                              0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (20736, 22)

# %%
# detecting duplicate rows
df.duplicated().sum()
# Out:
# 12

# %%
df[df.duplicated()]
# Out:
#                  id                                               name  \
# 6      4.527754e+07  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 7      9.710000e+17  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 8      3.857863e+06  Rental unit in New York · ★4.64 · 1 bedroom · ...
# 9      4.089661e+07  Condo in New York · ★4.91 · Studio · 1 bed · 1...
# 10     4.958498e+07  Rental unit in New York · ★5.0 · 1 bedroom · 1...
# 20736  7.990000e+17  Rental unit in New York · 2 bedrooms · 2 beds ...
# 20737  5.930000e+17  Rental unit in New York · ★4.79 · 2 bedrooms ·...
# 20738  9.230000e+17  Loft in New York · ★4.33 · 1 bedroom · 2 beds ...
# 20739  1.336161e+07  Rental unit in New York · ★4.89 · 2 bedrooms ·...
# 20740  5.119566e+07  Rental unit in New York · Studio · 1 bed · 1 bath
# 20741  2.523473e+07  Rental unit in New York · ★4.41 · 1 bedroom · ...
# 20742  3.339399e+06  Rental unit in New York · ★4.73 · 1 bedroom · ...
#
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (20724, 22)

# %%
df.dtypes
# Out:
# id                                float64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                    float64
# number_of_reviews                 float64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count    float64
# availability_365                  float64
# number_of_reviews_ltm             float64
# license                            object
# rating                             object
# bedrooms                           object
# beds                                int64
# baths                              object
# dtype: object

# %%
df['id']=df['id'].astype('object')

# %%
df['host_id']=df['host_id'].astype('object')

# %%
#task 5 :data analysis 
df['price'].describe()
# Out:
# count     20724.000000
# mean        187.732195
# std        1023.539393
# min          10.000000
# 25%          80.000000
# 50%         125.000000
# 75%         199.000000
# max      100000.000000
# Name: price, dtype: float64

# %%
sns.histplot(df['price'], bins=30, kde=True)
plt.title('Distribution of Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
#identifying outliers using boxplot
plt.figure(figsize=(10,6))
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=df, x='price')
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
data=df[df['price']<1500]

# %%
data.head(2)
# Out:
#            id                                               name   host_id  \
# 0   1312228.0         Rental unit in Brooklyn · ★5.0 · 1 bedroom   7130382
# 1  45277537.0  Rental unit in New York · ★4.67 · 2 bedrooms ·...  51501835
#
#   host_name neighbourhood_group   neighbourhood  latitude  longitude  \
# 0    Walter            Brooklyn    Clinton Hill  40.68371  -73.96461
# 1  Jeniffer           Manhattan  Hell's Kitchen  40.76661  -73.98810
#
#          room_type  price  ...  last_review  reviews_per_month  \
# 0     Private room   55.0  ...     20/12/15               0.03
# 1  Entire home/apt  144.0  ...     01/05/23               0.24
#
#   calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 0                            1.0               0.0                    0.0
# 1                          139.0             364.0                    2.0
#
#       license  rating bedrooms beds          baths
# 0  No License       5        1    1  Not specified
# ...

# %%
data.shape
# Out:
# (20636, 22)

# %%
df.shape
# Out:
# (20724, 22)

# %%
df.head(4)
# Out:
#                      id                                               name  \
# 0             1312228.0         Rental unit in Brooklyn · ★5.0 · 1 bedroom
# 1            45277537.0  Rental unit in New York · ★4.67 · 2 bedrooms ·...
# 2  971000000000000000.0  Rental unit in New York · ★4.17 · 1 bedroom · ...
# 3             3857863.0  Rental unit in New York · ★4.64 · 1 bedroom · ...
#
#      host_id           host_name neighbourhood_group       neighbourhood  \
# 0    7130382              Walter            Brooklyn        Clinton Hill
# 1   51501835            Jeniffer           Manhattan      Hell's Kitchen
# 2  528871354              Joshua           Manhattan             Chelsea
# 3   19902271  John And Catherine           Manhattan  Washington Heights
#
#     latitude  longitude        room_type  price  ...  last_review  \
# 0  40.683710 -73.964610     Private room   55.0  ...     20/12/15
# 1  40.766610 -73.988100  Entire home/apt  144.0  ...     01/05/23
# ...

# %%
plt.figure(figsize=(6,3))
sns.histplot(data=data, x='price', bins=30, kde=True)
plt.title('Distribution of Prices ')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
gb=df.groupby('neighbourhood_group')['price'].mean().reset_index()

# %%
plt .pie(gb['price'], labels=gb['neighbourhood_group'], autopct='%1.1f%%', startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x17c666c30>,
# ...
#  [Text(-1.0734154205603614, 0.24037332402582146, 'Bronx'),
#   Text(-0.5822837908611016, -0.9332446554363036, 'Brooklyn'),
#   Text(0.9881933972914557, -0.4831912763591366, 'Manhattan'),
#   Text(0.617999332494316, 0.9099872664145252, 'Queens'),
#   Text(-0.4215921031891328, 1.0160020169904014, 'Staten Island')],
#  [Text(-0.5854993203056517, 0.13111272219590261, '15.2%'),
#   Text(-0.31760934046969175, -0.5090425393288929, '24.0%'),
#   Text(0.539014580340794, -0.26355887801407446, '29.2%'),
#   Text(0.33709054499689967, 0.49635669077155914, '16.3%'),
#   Text(-0.22995932901225424, 0.5541829183584006, '15.3%')])

# %%
gb
# Out:
#   neighbourhood_group       price
# 0               Bronx  118.407798
# 1            Brooklyn  187.196647
# 2           Manhattan  227.585979
# 3              Queens  126.521415
# 4       Staten Island  118.780069

# %%
sns.scatterplot(data=df, x='longitude', y='latitude', hue='neighbourhood_group', alpha=0.5)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
sns.barplot(x='neighbourhood_group', y='price', data=gb)
plt.title('Average Price by Neighbourhood Group')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Average Price')
plt.show()

# %%
sns.scatterplot(data=data, x='number_of_reviews', y='price', hue='neighbourhood_group', alpha=0.5)
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='price'>
